# %% [markdown]
# This cell imports the pandas library, commonly used for data manipulation and analysis, and numpy for numerical operations. Both are imported with standard aliases pd and np respectively.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# This cell reads the CSV file located at /content/logs_dataset.csv into a pandas DataFrame named df. This is the first step to load the dataset for analysis.

# %%
df=pd.read_csv("/content/logs_dataset.csv")

# %% [markdown]
# This cell displays the first 5 rows of the DataFrame df. This is a common practice to quickly inspect the structure and content of the loaded data.

# %%
print(df.head())
# Out:
#                     @timestamp                   _id  ip_address
# 0  July 8th 2019, 14:43:03.000  XswJ0msBoTGddM7vxMDB  10.1.1.285
# 1  July 8th 2019, 14:43:01.000  dKQJ0msB7mP0GwVzvJjz  10.1.2.389
# 2  July 8th 2019, 14:42:59.000  CcwJ0msBoTGddM7vtb8y  10.1.1.415
# 3  July 8th 2019, 14:42:57.000  bKQJ0msB7mP0GwVzrZdT   10.1.1.79
# 4  July 8th 2019, 14:42:55.000  L6QJ0msB7mP0GwVzpZeI   10.1.1.60

# %% [markdown]
# This cell prints the total number of rows (entries) in the DataFrame df using the len() function. This gives an idea of the dataset's size.

# %%
print(len(df))
# Out:
# 721547

# %%
print(len(df))
# Out:
# 721547

# %%
print(len(df.index))
# Out:
# 721547

# %% [markdown]
# This cell generates descriptive statistics of the DataFrame df. For object (string) columns, it provides count, unique values, top occurring value, and its frequency. For numerical columns, it would provide count, mean, std, min, max, and quartiles, although there are no numerical columns in the head displayed earlier.

# %%
df.describe()
# Out:
#                           @timestamp     _id ip_address
# count                         721547  721547     721547
# unique                        706029  712431        386
# top     June 11th 2019, 15:23:06.001  #NAME?  10.1.2.63
# freq                             928    9115       4372
